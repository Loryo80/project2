# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Senhaji Yassine**
#
# Actually i'm following a course in coursera about **DATA SCIENCE**  and i hope it will define my future occupation

# %% [markdown]
#
# *i'm interested in Data Science because i believe in the power of data and all the potential of the data driven solutions*

# %% [markdown]
# ### function to calculate the power squared of a given variable

# %%
x = 5348

def power_squared(x):
    x = x*x
    print(x)

power_squared(x)
# Out:
# 28601104

# %% [markdown]
# ![data_science_1.jpg](attachment:503e8cd4-e0ce-44c0-a301-dcd6733218b1.jpg)
#
# # DATA SCIENCE's Wikipedia article
#
# In this article we can find some informations about DATA SCIENCE like :
#  - Foundations
#  - Etymology
#  - References
#
#
#  if you want more details you can visit the article [here](https://en.wikipedia.org/wiki/Data_science)
